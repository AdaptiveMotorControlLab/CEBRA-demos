# %% [markdown]
# # Using xCEBRA: Time-series attribution maps with regularized contrastive learning
#
# **AISTATS 2025**
#
# - **ABSTRACT**: Gradient-based attribution methods aim to explain decisions of deep learning models but so far lack identifiability guarantees. Here, we propose a method to generate attribution maps with identifiability guarantees by developing a regularized contrastive learning algorithm trained on time-series data plus a new attribution method called Inverted Neuron Gradient (collectively named xCEBRA). We show theoretically that xCEBRA has favorable properties for identifying the Jacobian matrix of the data generating process. Empirically, we demonstrate robust approximation of zero vs. non-zero entries in the ground-truth attribution map on synthetic datasets, and significant improvements across previous attribution methods based on feature ablation, Shapley values, and other gradient-based methods. Our work constitutes a first example of identifiable inference of time-series attribution maps and opens avenues to a better understanding of time-series data, such as for neural dynamics and decision-processes within neural networks.
#
# - If you find this helpful, please cite: Schneider, Steffen, et al. *Time-Series Attribution Maps with Regularized Contrastive Learning*. The 28th International Conference on Artificial Intelligence and Statistics, 2025. [https://openreview.net/forum?id=aGrCXoTB4P](https://openreview.net/forum?id=aGrCXoTB4P).

# %%
# !pip install "git+https://github.com/AdaptiveMotorControlLab/CEBRA.git#egg=CEBRA[integrations]"
# Out:
# DEPRECATION: git+https://github.com/AdaptiveMotorControlLab/CEBRA.git#egg=CEBRA[integrations] contains an egg fragment with a non-PEP 508 name. pip 25.1 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/13157
# Collecting CEBRA (from CEBRA[integrations])
#   Cloning https://github.com/AdaptiveMotorControlLab/CEBRA.git to /private/var/folders/ct/4w_vk2wn10xb_xj2fm7d6vqc0000gn/T/pip-install-amys1__t/cebra_2ebfe67d66014550be6bb3d5c2510735
#   Running command git clone --filter=blob:none --quiet https://github.com/AdaptiveMotorControlLab/CEBRA.git /private/var/folders/ct/4w_vk2wn10xb_xj2fm7d6vqc0000gn/T/pip-install-amys1__t/cebra_2ebfe67d66014550be6bb3d5c2510735
#   Resolved https://github.com/AdaptiveMotorControlLab/CEBRA.git to commit 92c8b1f21a7d1c70cabcc956b0bdbabd8d210b0e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (1.4.2)
# Requirement already satisfied: numpy in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (1.26.4)
# Requirement already satisfied: literate-dataclasses in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (0.0.6)
# Requirement already satisfied: scikit-learn in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (1.6.1)
# Requirement already satisfied: scipy in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (1.15.2)
# Requirement already satisfied: torch>=2.4.0 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (2.6.0)
# Requirement already satisfied: tqdm in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (4.67.1)
# Requirement already satisfied: matplotlib<3.11 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (3.10.1)
# Requirement already satisfied: requests in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (2.32.3)
# Requirement already satisfied: pandas in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (2.2.3)
# Requirement already satisfied: plotly in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (6.0.1)
# Requirement already satisfied: seaborn in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (0.13.2)
# Requirement already satisfied: captum in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (0.8.0)
# Requirement already satisfied: cvxpy in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (1.6.5)
# Requirement already satisfied: scikit-image in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from CEBRA->CEBRA[integrations]) (0.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from matplotlib<3.11->CEBRA->CEBRA[integrations]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from matplotlib<3.11->CEBRA->CEBRA[integrations]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from matplotlib<3.11->CEBRA->CEBRA[integrations]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from matplotlib<3.11->CEBRA->CEBRA[integrations]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from matplotlib<3.11->CEBRA->CEBRA[integrations]) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from matplotlib<3.11->CEBRA->CEBRA[integrations]) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from matplotlib<3.11->CEBRA->CEBRA[integrations]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from matplotlib<3.11->CEBRA->CEBRA[integrations]) (2.9.0.post0)
# Requirement already satisfied: filelock in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from torch>=2.4.0->CEBRA->CEBRA[integrations]) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from torch>=2.4.0->CEBRA->CEBRA[integrations]) (4.13.2)
# Requirement already satisfied: networkx in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from torch>=2.4.0->CEBRA->CEBRA[integrations]) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from torch>=2.4.0->CEBRA->CEBRA[integrations]) (3.1.6)
# Requirement already satisfied: fsspec in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from torch>=2.4.0->CEBRA->CEBRA[integrations]) (2025.3.2)
# Requirement already satisfied: setuptools in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from torch>=2.4.0->CEBRA->CEBRA[integrations]) (79.0.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from torch>=2.4.0->CEBRA->CEBRA[integrations]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from sympy==1.13.1->torch>=2.4.0->CEBRA->CEBRA[integrations]) (1.3.0)
# Requirement already satisfied: osqp>=0.6.2 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from cvxpy->CEBRA->CEBRA[integrations]) (1.0.3)
# Requirement already satisfied: clarabel>=0.5.0 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from cvxpy->CEBRA->CEBRA[integrations]) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from cvxpy->CEBRA->CEBRA[integrations]) (3.2.7.post2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from pandas->CEBRA->CEBRA[integrations]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from pandas->CEBRA->CEBRA[integrations]) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from plotly->CEBRA->CEBRA[integrations]) (1.36.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from requests->CEBRA->CEBRA[integrations]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from requests->CEBRA->CEBRA[integrations]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from requests->CEBRA->CEBRA[integrations]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from requests->CEBRA->CEBRA[integrations]) (2025.1.31)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from scikit-image->CEBRA->CEBRA[integrations]) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from scikit-image->CEBRA->CEBRA[integrations]) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from scikit-image->CEBRA->CEBRA[integrations]) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from scikit-learn->CEBRA->CEBRA[integrations]) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib<3.11->CEBRA->CEBRA[integrations]) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mwmathis/miniconda/envs/DEEPLABCUT/lib/python3.13/site-packages (from jinja2->torch>=2.4.0->CEBRA->CEBRA[integrations]) (3.0.2)

# %%
import pickle
import torch
import numpy as np

import matplotlib.pyplot as plt
from cebra.data import DatasetxCEBRA, ContrastiveMultiObjectiveLoader
import cebra
from cebra.data import TensorDataset

from cebra.solver import MultiObjectiveConfig
from cebra.solver.schedulers import LinearRampUp
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# ## Load the data & create dataset

# %%
# download the data from: https://zenodo.org/record/15267195/
import requests

url = "https://zenodo.org/records/15267195/files/cynthi_neurons90_gridbase0.5_gridmodules3_grid_head_direction_place_speed_duration2000_noise0.25_bs100_seed231209234.p?download=1"
response = requests.get(url)

with open("cynthi_neurons90.p", "wb") as f:
    f.write(response.content)

# %%
file = "cynthi_neurons90.p"
with open(file, 'rb') as f:
    dataset = pickle.load(f)

neural = torch.FloatTensor(dataset['spikes']).float()
position = torch.FloatTensor(dataset['position']).float()
ground_truth_attribution = dataset['ground_truth_attribution']
# create dataset
data = DatasetxCEBRA(
    neural, 
    position=position
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 7
#       5 neural = torch.FloatTensor(dataset['spikes']).float()
#       6 position = torch.FloatTensor(dataset['position']).float()
# ----> 7 ground_truth_attribution = dataset['ground_truth_attribution']
#       8 # create dataset
#       9 data = DatasetxCEBRA(
#      10     neural,
#      11     position=position
#      12 )
#
# KeyError: 'ground_truth_attribution'

# %% [markdown]
# ## Visualize neural data and position

# %%
plt.matshow(neural.T, aspect="auto", cmap="Greys")
plt.ylabel("Neurons")
plt.xlabel("Time")
plt.show()

# %%
plt.figure(figsize=(8, 8))  # Set a larger figure size
traj_to = 2000
highlight_range = slice(250, 260)
plt.plot(position[0::,0], position[0::,1], 'k', linewidth=0.1, alpha=0.45)
cl = plt.scatter(position[0:traj_to,0], position[0:traj_to,1], c=np.arange(0, traj_to), cmap='RdPu', s=15)
plt.xlabel('Position X')
plt.ylabel('Position Y')
plt.show()

# %%
plt.matshow(dataset['ground_truth_attribution'], aspect="auto")
plt.title("Ground truth attribution map")
plt.xlabel("Neurons")
plt.ylabel("Latents")
plt.colorbar()
plt.show()

# %% [markdown]
# ## Train a model

# %% [markdown]
# ### 1. Define parameters

# %%
behavior_indices = (0, 4)
time_indices = (0, 14)

num_steps = 10_000
device = "cuda"
n_latents = 14

# %% [markdown]
# ### 2. Define loader, model and solver

# %%
loader = ContrastiveMultiObjectiveLoader(dataset=data,
                                         num_steps=num_steps,
                                         batch_size=2_500).to(device)
config = MultiObjectiveConfig(loader)

config.set_slice(*behavior_indices)
config.set_loss("FixedCosineInfoNCE", temperature=1.)
config.set_distribution("time_delta", time_delta=1, label_name="position")
config.push()

config.set_slice(*time_indices)
config.set_loss("FixedCosineInfoNCE", temperature=1.)
config.set_distribution("time", time_offset=10)
config.push()

config.finalize()

criterion = config.criterion
feature_ranges = config.feature_ranges


neural_model = cebra.models.init(
    name="offset10-model",
    num_neurons=data.neural.shape[1],
    num_units=256,
    num_output=n_latents,
).to(device)

data.configure_for(neural_model)

opt = torch.optim.Adam(
    list(neural_model.parameters()) + list(criterion.parameters()),
    lr=3e-4,
    weight_decay=0,
) 

regularizer = cebra.models.jacobian_regularizer.JacobianReg()

solver = cebra.solver.init(
    name="multiobjective-solver",
    model=neural_model,
    feature_ranges=feature_ranges,
    regularizer = regularizer,
    renormalize=True,
    use_sam=False,
    criterion=criterion,
    optimizer=opt,
    tqdm_on=True,
).to(device)

# %% [markdown]
# ### 3. Define weight scheduler for regularizer and train model

# %%
weight_scheduler = LinearRampUp(
    n_splits=2,
    step_to_switch_on_reg= num_steps // 4,
    step_to_switch_off_reg= num_steps // 2,
    start_weight=0.,
    end_weight=0.1, 
)

solver.fit(loader=loader,
           valid_loader=None,
           log_frequency=None,
           scheduler_regularizer = weight_scheduler,
           scheduler_loss = None,
)

# %%
# Plot every key in solver.log
keys = list(solver.log.keys())
for i in range(0, len(keys), 4):
    fig, axs = plt.subplots(1, 4, figsize=(20, 5))
    for j, key in enumerate(keys[i:i+4]):
        axs[j].plot(solver.log[key])
        axs[j].set_title(f"Plot for {key}")
        axs[j].set_xlabel("Steps")
        # axs[j].set_ylabel("Value")
    plt.show()

# %% [markdown]
# ## Compute embedding

# %%
data_emb = TensorDataset(neural, continuous=torch.zeros(len(data.neural)))
data_emb.configure_for(solver.model)
data_emb = data_emb[torch.arange(len(data_emb))]

solver.model.split_outputs = False
embedding = solver.model(data_emb.to(device)).detach().cpu()

# %% [markdown]
# ## Compute R2 / KNN score

# %%
time_indices_for_score = slice(4, 14)

# %%
X_behavior = embedding[:, slice(*behavior_indices)]
X_time = embedding[:, time_indices_for_score]
y = position

# Linear regression
linear_model_time = LinearRegression()
R2_time = linear_model_time.fit(X_time, y).score(X_time, y)

linear_model_behavior = LinearRegression()
R2_behavior = linear_model_behavior.fit(X_behavior, y).score(X_behavior, y)

print(f"R2 time: {R2_time: .2f}")
print(f"R2 behavior: {R2_behavior: .2f}")

# %%
tscv = TimeSeriesSplit(n_splits=5)
knn_model_time = KNeighborsRegressor()
knn_model_behavior = KNeighborsRegressor()

average_KNN_time = []
average_KNN_behavior = []

# Time series cross-validation for time features
for train_index, val_index in tscv.split(X_time):
    X_time_train, X_time_val = X_time[train_index], X_time[val_index]
    y_time_train, y_time_val = y[train_index], y[val_index]
    knn_model_time.fit(X_time_train, y_time_train)
    average_KNN_time.append(knn_model_time.score(X_time_val, y_time_val))

# Time series cross-validation for behavior features
for train_index, val_index in tscv.split(X_behavior):
    X_behavior_train, X_behavior_val = X_behavior[train_index], X_behavior[val_index]
    y_behavior_train, y_behavior_val = y[train_index], y[val_index]
    knn_model_behavior.fit(X_behavior_train, y_behavior_train)
    average_KNN_behavior.append(knn_model_behavior.score(X_behavior_val, y_behavior_val))

# Calculate the average R2 scores
average_KNN_time = sum(average_KNN_time) / tscv.n_splits
average_KNN_behavior = sum(average_KNN_behavior) / tscv.n_splits

print(f"KNN score time: {average_KNN_time: .2f}")
print(f"KNN score behavior: {average_KNN_behavior: .2f}")

# %%
fig = plt.figure(figsize=(20, 15))

idx0_behavior, idx1_behavior, idx2_behavior = 0,1,2
idx0_time, idx1_time, idx2_time = 4,5,6
min_, max_ = 0, 10_000

ax1 = fig.add_subplot(121, projection='3d')
scatter1 = ax1.scatter(embedding[:, idx0_time][min_:max_],
                       embedding[:, idx1_time][min_:max_],
                       embedding[:, idx2_time][min_:max_],
                       c=position[:, 0][min_:max_], s=1, cmap="cool")
ax1.set_title(f'embedding (time contrastive), KNN/R2: {average_KNN_time: .2f} / {R2_time: .2f}', y=1.0, pad=-10)
ax1.set_axis_off()

ax2 = fig.add_subplot(122, projection='3d')
scatter2 = ax2.scatter(embedding[:, idx0_behavior][min_:max_],
                       embedding[:, idx1_behavior][min_:max_],
                       embedding[:, idx2_behavior][min_:max_],
                       c=position[:, 1][min_:max_], s=1, cmap="cool")
ax2.set_title(f'embedding (behavior contrastive), KNN/R2: {average_KNN_behavior: .2f} / {R2_behavior: .2f}', y=1.0, pad=-10)
ax2.set_axis_off()

plt.show()

# %% [markdown]
# ## Compute attribution map, AUC and visualize it

# %%
attribution_split = 'train'
model = solver.model.to(device)
model.split_outputs = False
neural.requires_grad_(True)

method = cebra.attribution.init(
    name="jacobian-based",
    model=model,
    input_data=neural,
    output_dimension=model.num_output
    )

result = method.compute_attribution_map()

# %%
jf = abs(result['jf']).mean(0)
jfinv = abs(result['jf-inv-svd']).mean(0)
jfconvabsinv = abs(result['jf-convabs-inv-svd']).mean(0)

# %%
plt.matshow(jf, aspect="auto")
plt.colorbar()
plt.title("Attribution map of JF")
plt.show()

# %%
plt.matshow(jfinv, aspect="auto")
plt.colorbar()
plt.title("Attribution map of JFinv")
plt.show()

# %%
auc_jf = method.compute_attribution_score(jf, ground_truth_attribution)
auc_jfinv = method.compute_attribution_score(jfinv,  ground_truth_attribution)
auc_jfconvabsinv = method.compute_attribution_score(jfconvabsinv,  ground_truth_attribution)
print(f"auc_jf, {auc_jf: .2f}")
print(f"auc_jfinv, {auc_jfinv: .2f}")
print(f"auc_jfconvabsinv, {auc_jfconvabsinv: .2f}")
